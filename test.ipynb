# %%
import csv

g = 'Subject_classmark.csv'

with open(F"{g}", newline='') as csvfile:
    data = list(csv.reader(csvfile))

print(data)
# Out:
# [['Subject', 'Classmark', '', '', ''], ['Accountancy', 'HF', '', '', ''], ['American History', 'E, F', '', '', ''], ['American Literature', 'PS', '', '', ''], ['Archaeology', 'CC', '', '', ''], ['Art', 'N', '', '', ''], ['Astrophysics', 'QB', '', '', ''], ['Biochemistry', 'QP, RB', '', '', ''], ['Biology', 'QH', '', '', ''], ['Biomedical Science', 'QR, RB', '', '', ''], ['Botany', 'QK, S', '', '', ''], ['British History', 'DA', '', '', ''], ['Business ', 'HD, HE, HF', '', '', ''], ['Chemistry', 'QD', '', '', ''], ['Chinese', 'PL', '', '', ''], ['Computing', 'QA, TK', '', '', ''], ['Counselling and Psychotherapy', 'RC', '', '', ''], ['Criminology', 'HV', '', '', ''], ['Ecology', 'QH', '', '', ''], ['Economics', 'HA, HB, HC, HD, HE, HF, HJ', '', '', ''], ['Education', 'L', '', '', ''], ['English Language', 'PE', '', '', ''], ['English Literature', 'PR', '', '', ''], ['Environmental Studies', 'GE, GF', '', '', ''], ['Film Studies', 'PN', '', '', ''], ['Film Studies', 'PN', '', '', ''], 
# ...

# %%
import csv

with open('Location_classmark.csv', newline='') as csvfile:
    # readcsv = csv.reader(csvfile)
    data1 = list(csv.reader(csvfile))

print(data1)
# Out:
# [['ï»¿Location', 'Classmark'], ['Back left', 'HM'], ['Back left', 'HN'], ['Back left', 'HO'], ['Back left', 'HP'], ['Back left', 'HQ'], ['Back left', 'HR'], ['Back left', 'HS'], ['Back left', 'HT'], ['Back left', 'HU'], ['Back left', 'HV'], ['Back left', 'HW'], ['Back left', 'HX'], ['Back left', 'HY'], ['Back left', 'HZ'], ['Back left', 'I'], ['Back left', 'IA'], ['Back left', 'IB'], ['Back left', 'IC'], ['Back left', 'ID'], ['Back left', 'IE'], ['Back left', 'IF'], ['Back left', 'IG'], ['Back left', 'IH'], ['Back left', 'II'], ['Back left', 'IJ'], ['Back left', 'IK'], ['Back left', 'IL'], ['Back left', 'IM'], ['Back left', 'IN'], ['Back left', 'IO'], ['Back left', 'IP'], ['Back left', 'IQ'], ['Back left', 'IR'], ['Back left', 'IS'], ['Back left', 'IT'], ['Back left', 'IU'], ['Back left', 'IV'], ['Back left', 'IW'], ['Back left', 'IX'], ['Back left', 'IY'], ['Back left', 'IZ'], ['Back left', 'J'], ['Back left', 'JA'], ['Back left', 'JB'], ['Back left', 'JC'], ['Back left', 'JD'], ['B
# ...

# %%
import csv

def readcsv(csv1, csv2):


    with open(f"{csv1}", newline='') as csvfile:
        data1 = list(csv.reader(csvfile))

    with open(F'{csv2}', newline='') as csvfile:
        data2 = list(csv.reader(csvfile))
    

    return data1,data2

# %%
from csv import DictReader

file_handler1 = open("Subject_classmark.csv", "r", encoding="utf8")
csv_handler1 = DictReader(file_handler1)

for row in csv_handler1:
    print(row)
# Out:
# {'Subject': 'Accountancy', 'Classmark': 'HF'}
# {'Subject': 'American History', 'Classmark': 'E, F'}
# {'Subject': 'American Literature', 'Classmark': 'PS'}
# {'Subject': 'Archaeology', 'Classmark': 'CC'}
# {'Subject': 'Art', 'Classmark': 'N'}
# {'Subject': 'Astrophysics', 'Classmark': 'QB'}
# {'Subject': 'Biochemistry', 'Classmark': 'QP, RB'}
# {'Subject': 'Biology', 'Classmark': 'QH'}
# {'Subject': 'Biomedical Science', 'Classmark': 'QR, RB'}
# {'Subject': 'Botany', 'Classmark': 'QK, S'}
# {'Subject': 'British History', 'Classmark': 'DA'}
# {'Subject': 'Business ', 'Classmark': 'HD, HE, HF'}
# {'Subject': 'Chemistry', 'Classmark': 'QD'}
# {'Subject': 'Chinese', 'Classmark': 'PL'}
# {'Subject': 'Computing', 'Classmark': 'QA, TK'}
# {'Subject': 'Counselling and Psychotherapy', 'Classmark': 'RC'}
# {'Subject': 'Criminology', 'Classmark': 'HV'}
# {'Subject': 'Ecology', 'Classmark': 'QH'}
# {'Subject': 'Economics', 'Classmark': 'HA, HB, HC, HD, HE, HF, HJ'}
# ...

# %%
from csv import DictReader

from typing import List, Dict


table: List[Dict[str, str]] = []

# def searchresult(param, search):
file_handler1 = open("Subject_classmark.csv", "r", encoding="utf8")
csv_handler1 = DictReader(file_handler1)

for row in csv_handler1:
    table.append({'Subject': row['Subject'], 'Classmark': row['Classmark']})

file_handler2 = open("Location_classmark2.csv", "r", encoding="utf8")
csv_handler2 = DictReader(file_handler2)

for row in csv_handler2:
    table.append({'Location': row['Location']})

final = [csv_handler1, csv_handler2]

print(table)
# for row in table:
#     print(row)
# Out:
# [{'Subject': 'Accountancy', 'Classmark': 'HF'}, {'Subject': 'American History', 'Classmark': 'E, F'}, {'Subject': 'American Literature', 'Classmark': 'PS'}, {'Subject': 'Archaeology', 'Classmark': 'CC'}, {'Subject': 'Art', 'Classmark': 'N'}, {'Subject': 'Astrophysics', 'Classmark': 'QB'}, {'Subject': 'Biochemistry', 'Classmark': 'QP, RB'}, {'Subject': 'Biology', 'Classmark': 'QH'}, {'Subject': 'Biomedical Science', 'Classmark': 'QR, RB'}, {'Subject': 'Botany', 'Classmark': 'QK, S'}, {'Subject': 'British History', 'Classmark': 'DA'}, {'Subject': 'Business ', 'Classmark': 'HD, HE, HF'}, {'Subject': 'Chemistry', 'Classmark': 'QD'}, {'Subject': 'Chinese', 'Classmark': 'PL'}, {'Subject': 'Computing', 'Classmark': 'QA, TK'}, {'Subject': 'Counselling and Psychotherapy', 'Classmark': 'RC'}, {'Subject': 'Criminology', 'Classmark': 'HV'}, {'Subject': 'Ecology', 'Classmark': 'QH'}, {'Subject': 'Economics', 'Classmark': 'HA, HB, HC, HD, HE, HF, HJ'}, {'Subject': 'Education', 'Classmark': 'L'}, {
# ...

# %%
new_data_dict = {}

file_handler1 = open("Subject_classmark.csv", "r", encoding="utf8")
csv_handler1 = DictReader(file_handler1)

file_handler2 = open("Location_classmark3.csv", "r", encoding="utf8")
csv_handler2 = DictReader(file_handler2)

for k1, v1 in zip(csv_handler1,csv_handler2):
    subject, classmark = k1
    classmark1, location = v1
    new_data_dict[classmark] = {subject: k1['Subject'], classmark1: v1['Classmark'], location: v1['Location']}


    for a in new_data_dict:
        print(new_data_dict[a]["Subject"])
        
        # for b in new_data_dict[a]:
# Out:
# Accountancy
# American History
# American Literature
# Archaeology
# Art
# Astrophysics
# Biochemistry
# Biology
# Biomedical Science
# Botany
# British History
# Business
# Chemistry
# Chinese
# Computing
# Counselling and Psychotherapy
# Criminology
# Ecology
# Economics
# Education
# English Language
# English Literature
# Environmental Studies
# Film Studies
# Finance
# Forensic Science
# French
# Geography
# Geology and Geoscience
# German
# History
# Human Biology
# Human Resource Management
# International Law
# International Relations
# Italian
# Japanese
# Law
# Management and Marketing
# Mathematics
# Media Studies
# Medicinal Chemistry
# Medicine
# Mental Health
# Neuroscience
# Nursing
# Pharmacology
# Pharmacy
# Philosophy
# Physics
# Physiology
# Physiotherapy
# Politics
# Psychology
# Radiography
# Religion
# Russian
# Social Work
# Sociology
# Spanish
# Veterinary Medicine

# %%
from csv import DictReader

from typing import List, Dict


new_data_dict = {}


def main():
    menuInput()

def menu():
    menuDisplay = print('''
    Welcome! Please make a choice from the following menu:
    1. Subject name
    2. Classmark
    3. Location
''')

    
    


def menu2():
    menuDisplay = print('''
    Welcome! Please make a choice from the following menu:
    1. Top Floor Back Left
    2. Top Floor Back Right
    3. Top Floor Front Left
    4. Top Floor Front Right
    5. Middle Floor
    3. Ground Floor
''')

def menuInput():
    global userChoice
    global userChoice2 
    
    while True:
        menu()
        try:
            userChoice = input("Please make a selection: ")
        except ValueError:
            print("Please enter a valid choice")
        
        if userChoice == "Subject name":
            userChoice2 = input("Please enter a Subject name: ")
            return userChoice2
        elif userChoice == "Classmark":
            userChoice2 = input("Please enter a Classmark: ")
            return userChoice2
        elif userChoice == "Location":
            menu2()
            userChoice2 = input("Please make a selection: ")
            exit()
            # if Location_userChoice == "Top Floor Back Left":
            #     return Location_userChoice
            # elif Location_userChoice == "Top Floor Back Right":
            #     return Location_userChoice
            # elif Location_userChoice == "Top Floor Front Left":
            #     return Location_userChoice
            # elif Location_userChoice == "Top Floor Front Right":
            #     return Location_userChoice
            # elif Location_userChoice == "Middle Floor":
            #     return Location_userChoice
            # elif Location_userChoice == "Ground Floor":
            #     return Location_userChoice
            # else:
            #     print("Thank you! Program Exiting!")
            #     exit()
                
print(userChoice2)
def searchresult(param, search):

    file_handler1 = open("Subject_classmark.csv", "r", encoding="utf8")
    csv_handler1 = DictReader(file_handler1)

    file_handler2 = open("Location_classmark3.csv", "r", encoding="utf8")
    csv_handler2 = DictReader(file_handler2)

    for k1, v1 in zip(csv_handler1,csv_handler2):
        subject, classmark = k1
        classmark1, location = v1
        new_data_dict[classmark] = {subject: k1['Subject'], classmark1: v1['Classmark'], location: v1['Location']}


        # for a in new_data_dict["Classmark"]["Location"]:
        #     print(a)

        # for row in new_data_dict:
        #     print(row)
        for row in new_data_dict:
            if param == "Subject Name":
                if search in new_data_dict[row]["Subject"]:
                    print('Related Subject: ' + new_data_dict[row]["Subject"] + ' Related Classmark: ' + new_data_dict[row]["Classmark"] + ' Related Location: ' + new_data_dict[row]["Location"])

            elif param == "Classmark":
                if search in new_data_dict[row]["Classmark"]:
                    print('Related Subject: ' + new_data_dict[row]["Subject"] + ' Related Classmark: ' + new_data_dict[row]["Classmark"] + ' Related Location: ' + new_data_dict[row]["Location"])
            
            elif param == "Location":
                if search in new_data_dict[row]["Location"]:
                    print('Related Subject: ' + new_data_dict[row]["Subject"] + ' Related Classmark: ' + new_data_dict[row]["Classmark"] + ' Related Location: ' + new_data_dict[row]["Location"])


# option = input('enter search parameter: ')
# value = input('enter value: ')

main()

searchresult(f"{userChoice}", f"{userChoice2}")
# Out:
# Art
#
#     Welcome! Please make a choice from the following menu:
#     1. Subject name
#     2. Classmark
#     3. Location
#
#
#     Welcome! Please make a choice from the following menu:
#     1. Top Floor Back Left
#     2. Top Floor Back Right
#     3. Top Floor Front Left
#     4. Top Floor Front Right
#     5. Middle Floor
#     3. Ground Floor
#
#
#     Welcome! Please make a choice from the following menu:
#     1. Subject name
#     2. Classmark
#     3. Location
#
#
#     Welcome! Please make a choice from the following menu:
#     1. Subject name
#     2. Classmark
#     3. Location
#
#
#     Welcome! Please make a choice from the following menu:
#     1. Subject name
#     2. Classmark
#     3. Location
#
#
#     Welcome! Please make a choice from the following menu:
#     1. Subject name
#     2. Classmark
#     3. Location
#
#
#     Welcome! Please make a choice from the following menu:
#     1. Subject name
#     2. Classmark
#     3. Location
#
#
# ...

# %%
from csv import DictReader
from collections import defaultdict


# def searchresult(param, search):
file_handler1 = open("Subject_classmark.csv", "r", encoding="utf8")
csv_handler1 = DictReader(file_handler1)

file_handler2 = open("Location_classmark3.csv", "r", encoding="utf8")
csv_handler2 = DictReader(file_handler2)

new_data_dict = defaultdict(dict)


for k1 in zip(csv_handler1,csv_handler2):
    item = new_data_dict.get(k1["Classmark"], dict())
    
    new_data_dict[k1["Classmark"]] = item
print(new_data_dict)

# print(classmark)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\KingRemy\Documents\CSC-40044 System Design & Programming\System Design Project\test.ipynb Cell 7 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/Documents/CSC-40044%20System%20Design%20%26%20Programming/System%20Design%20Project/test.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> new_data_dict = defaultdict(dict)
#      <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/Documents/CSC-40044%20System%20Design%20%26%20Programming/System%20Design%20Project/test.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> for k1 in zip(csv_handler1,csv_handler2):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/Documents/CSC-40044%20System%20Design%20%26%20Programming/System%20Design%20Project/test.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a>     item = new_data_dict.get(k1["Classmark"], dict())
# ...

# %%
from csv import DictReader

from typing import List, Dict

def searchresult(param, search):
    file_handler = open("Subject_classmark.csv", "r", encoding="utf8")
    csv_handler = DictReader(file_handler)

    table: List[Dict[str, str]] = []

    for row in csv_handler:
        if param == "Subject Name":
            if search in row['Subject']:
                print('Related Subject: ' + row['Subject'] + ' Related Classmark: ' + row['Classmark'])

        elif param == "Classmark":
            if search in row['Classmark']:
                print('Related Subject: ' + row['Subject'] + ' Related Classmark: ' + row['Classmark'])
        # str_row = row
        # table.append(str_row)
        # print(row)

searchresult('Subject Name', 'Computing')
# Out:
# Related Subject: Computing Related Classmark: QA, TK

# %%
def searchresult2(search):
    file_handler = open("Location_classmark2.csv", "r", encoding="utf8")
    csv_handler = DictReader(file_handler)
    
    for rowlocation in csv_handler:
        if search == rowlocation['Location']:
            print('Location: ' + rowlocation['Location'] + ' Classmark: ' + rowlocation['Classmark'])
            # searchresult('Related Subject', rowlocation['Location'])

searchresult2('Middle Floor')
# Out:
# Location: Middle Floor Classmark: CC
# Location: Middle Floor Classmark: DA
# Location: Middle Floor Classmark: D
# Location: Middle Floor Classmark: B, BA, BB, BC, BD, BE, BF, BG, BH, BI, BJ
# Location: Middle Floor Classmark: BF
# Location: Middle Floor Classmark: BL, BM, BN, BO, BP, BQ, BR, BS, BT, BU, BV, BW, BX

# %%
def menu():
    print("Select an option")
    print("1. Subject name")
    print("2. Classmark")
    print("3. Location")

menu()
search = input("Please make a choice: ")
for rows in table:
    if search == "Subject name":
        search_= input("Enter the subject name")
        if search_ in table
    elif search == "Classmark":
        search_= input("Enter the classmark")
    elif search == "Location":
        search_= input("Enter the location")
    else:
        print("Invalid Option, please try again")

# %%
search = input("Please select subject name, classmark or a location: ")
for i in range(len(data)):
    if search == (data[i][1]):
        print()
